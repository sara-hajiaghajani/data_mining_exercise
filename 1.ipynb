# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('‎Datapreprocessing.csv', index_col=0)
df
# Out:
#       DataSource    Unnamed:1 https://data.worldbank.org         Unnamed:3  \
# 0           Data          NaN                       2016               NaN
# 1    CountryName  CountryCode          Population growth  Total population
# 2         Brazil          BRA                0.817555711         207652865
# 3    Switzerland          CHE                1.077221168           8372098
# 4        Germany          DEU                1.193866758          82667685
# 5        Denmark          DNK                0.834637611               NaN
# 6          Spain          ESP               -0.008048086          46443959
# 7         France          FRA                0.407491036          66896109
# 8          Japan          JPN               -0.115284177         126994511
# 9         Greece          GRC               -0.687542545          10746740
# 10          Iran          IRN                  1.1487886          80277428
# ...

# %%
df = df.rename(columns={'DataSource': 'CountryName', 'Unnamed:1': 'CountryCode', 'https://data.worldbank.org': 'Population growth', 'Unnamed:3': 'Total population', 'Unnamed:4': 'Area (sq. km)', 'Unnamed: 6': 'International Visitors', 'Unnamed':'Coronavirus Cases'})
df
# Out:
#      CountryName  CountryCode  Population growth  Total population  \
# 0           Data          NaN               2016               NaN
# 1    CountryName  CountryCode  Population growth  Total population
# 2         Brazil          BRA        0.817555711         207652865
# 3    Switzerland          CHE        1.077221168           8372098
# 4        Germany          DEU        1.193866758          82667685
# 5        Denmark          DNK        0.834637611               NaN
# 6          Spain          ESP       -0.008048086          46443959
# 7         France          FRA        0.407491036          66896109
# 8          Japan          JPN       -0.115284177         126994511
# 9         Greece          GRC       -0.687542545          10746740
# 10          Iran          IRN          1.1487886          80277428
# 11        Kuwait          KWT        2.924206194           4052584
# 12       Morocco          MAR                NaN          35276786
# ...

# %%
df.drop([0,1],inplace=True)
df.drop(['CountryName','CountryCode'], axis=1,inplace=True)
df
# Out:
#    Population growth Total population Area (sq. km) International Visitors  \
# 2        0.817555711        207652865       8358140                      B
# 3        1.077221168          8372098         39516                      B
# 4        1.193866758         82667685        348900                      A
# 5        0.834637611              NaN         42262                      B
# 6       -0.008048086         46443959        500210                      A
# 7        0.407491036         66896109        547557                      A
# 8       -0.115284177        126994511        364560                      B
# 9       -0.687542545         10746740        128900                      C
# 10         1.1487886         80277428       1628760                      D
# 11       2.924206194          4052584           NaN                      C
# 12               NaN         35276786        446300                      C
# ...

# %%
df.insert(0, "index", list(range(0,15)), True)
df.set_index('index', inplace=True)
df
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0           0.817555711        207652865       8358140                      B
# 1           1.077221168          8372098         39516                      B
# 2           1.193866758         82667685        348900                      A
# 3           0.834637611              NaN         42262                      B
# 4          -0.008048086         46443959        500210                      A
# 5           0.407491036         66896109        547557                      A
# 6          -0.115284177        126994511        364560                      B
# 7          -0.687542545         10746740        128900                      C
# 8             1.1487886         80277428       1628760                      D
# 9           2.924206194          4052584           NaN                      C
# 10                  NaN         35276786        446300                      C
# ...

# %% [markdown]
# # Handling Missing Value

# %%
df.dropna()
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0           0.817555711        207652865       8358140                      B
# 1           1.077221168          8372098         39516                      B
# 2           1.193866758         82667685        348900                      A
# 4          -0.008048086         46443959        500210                      A
# 5           0.407491036         66896109        547557                      A
# 6          -0.115284177        126994511        364560                      B
# 7          -0.687542545         10746740        128900                      C
# 8             1.1487886         80277428       1628760                      D
# 11          2.619033526        185989640        910770                      D
# 12          3.495069918          2569804         11610                      B
# 14          1.148214693       1324171354       2973190                      B
#
#       Coronavirus Cases
# ...

# %%
df.dropna(axis=1)
# Out:
#       International Visitors Coronavirus Cases
# index
# 0                          B             59324
# 1                          B             29061
# 2                          A            156727
# 3                          B              8575
# 4                          A            223759
# 5                          A            161488
# 6                          B             13231
# 7                          C              2506
# 8                          D             90481
# 9                          C              3075
# 10                         C              4047
# 11                         D              1182
# 12                         B             10287
# 13                         C             18640
# 14                         B             26917

# %%
df.fillna(value=10000)
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0           0.817555711        207652865       8358140                      B
# 1           1.077221168          8372098         39516                      B
# 2           1.193866758         82667685        348900                      A
# 3           0.834637611            10000         42262                      B
# 4          -0.008048086         46443959        500210                      A
# 5           0.407491036         66896109        547557                      A
# 6          -0.115284177        126994511        364560                      B
# 7          -0.687542545         10746740        128900                      C
# 8             1.1487886         80277428       1628760                      D
# 9           2.924206194          4052584         10000                      C
# 10                10000         35276786        446300                      C
# ...

# %%
df.fillna(method='bfill')
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0           0.817555711        207652865       8358140                      B
# 1           1.077221168          8372098         39516                      B
# 2           1.193866758         82667685        348900                      A
# 3           0.834637611         46443959         42262                      B
# 4          -0.008048086         46443959        500210                      A
# 5           0.407491036         66896109        547557                      A
# 6          -0.115284177        126994511        364560                      B
# 7          -0.687542545         10746740        128900                      C
# 8             1.1487886         80277428       1628760                      D
# 9           2.924206194          4052584        446300                      C
# 10          2.619033526         35276786        446300                      C
# ...

# %%
df1=df.copy()
df1
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0           0.817555711        207652865       8358140                      B
# 1           1.077221168          8372098         39516                      B
# 2           1.193866758         82667685        348900                      A
# 3           0.834637611              NaN         42262                      B
# 4          -0.008048086         46443959        500210                      A
# 5           0.407491036         66896109        547557                      A
# 6          -0.115284177        126994511        364560                      B
# 7          -0.687542545         10746740        128900                      C
# 8             1.1487886         80277428       1628760                      D
# 9           2.924206194          4052584           NaN                      C
# 10                  NaN         35276786        446300                      C
# ...

# %%
from sklearn.impute import SimpleImputer
df1
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0           0.817555711        207652865       8358140                      B
# 1           1.077221168          8372098         39516                      B
# 2           1.193866758         82667685        348900                      A
# 3           0.834637611              NaN         42262                      B
# 4          -0.008048086         46443959        500210                      A
# 5           0.407491036         66896109        547557                      A
# 6          -0.115284177        126994511        364560                      B
# 7          -0.687542545         10746740        128900                      C
# 8             1.1487886         80277428       1628760                      D
# 9           2.924206194          4052584           NaN                      C
# 10                  NaN         35276786        446300                      C
# ...

# %%
imputer=SimpleImputer()
df1.iloc[:,0:3]=imputer.fit_transform(df1.iloc[:,0:3])
df1
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0              0.817556      2.07653e+08   8.35814e+06                      B
# 1               1.07722       8.3721e+06         39516                      B
# 2               1.19387      8.26677e+07        348900                      A
# 3              0.834638      1.56572e+08         42262                      B
# 4           -0.00804809       4.6444e+07        500210                      A
# 5              0.407491      6.68961e+07        547557                      A
# 6             -0.115284      1.26995e+08        364560                      B
# 7             -0.687543      1.07467e+07        128900                      C
# 8               1.14879      8.02774e+07   1.62876e+06                      D
# 9               2.92421      4.05258e+06   1.19343e+06                      C
# 10              1.14271      3.52768e+07        446300                      C
# ...

# %%
df_knn=df.copy()
df_knn
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0           0.817555711        207652865       8358140                      B
# 1           1.077221168          8372098         39516                      B
# 2           1.193866758         82667685        348900                      A
# 3           0.834637611              NaN         42262                      B
# 4          -0.008048086         46443959        500210                      A
# 5           0.407491036         66896109        547557                      A
# 6          -0.115284177        126994511        364560                      B
# 7          -0.687542545         10746740        128900                      C
# 8             1.1487886         80277428       1628760                      D
# 9           2.924206194          4052584           NaN                      C
# 10                  NaN         35276786        446300                      C
# ...

# %%
from sklearn.impute import KNNImputer

# %%
imputer=KNNImputer()
df_knn.iloc[:,0:3]=imputer.fit_transform(df_knn.iloc[:,0:3])
df_knn
# Out:
#       Population growth Total population Area (sq. km) International Visitors  \
# index
# 0              0.817556      2.07653e+08   8.35814e+06                      B
# 1               1.07722       8.3721e+06         39516                      B
# 2               1.19387      8.26677e+07        348900                      A
# 3              0.834638      2.16818e+07         42262                      B
# 4           -0.00804809       4.6444e+07        500210                      A
# 5              0.407491      6.68961e+07        547557                      A
# 6             -0.115284      1.26995e+08        364560                      B
# 7             -0.687543      1.07467e+07        128900                      C
# 8               1.14879      8.02774e+07   1.62876e+06                      D
# 9               2.92421      4.05258e+06        125920                      C
# 10             0.324752      3.52768e+07        446300                      C
# ...

# %% [markdown]
# # Encoding Categorical Attributes(Dummy Variables)

# %%
df2=pd.get_dummies(df_knn, columns=['International Visitors'])
df2
# Out:
#       Population growth Total population Area (sq. km) Coronavirus Cases  \
# index
# 0              0.817556      2.07653e+08   8.35814e+06             59324
# 1               1.07722       8.3721e+06         39516             29061
# 2               1.19387      8.26677e+07        348900            156727
# 3              0.834638      2.16818e+07         42262              8575
# 4           -0.00804809       4.6444e+07        500210            223759
# 5              0.407491      6.68961e+07        547557            161488
# 6             -0.115284      1.26995e+08        364560             13231
# 7             -0.687543      1.07467e+07        128900              2506
# 8               1.14879      8.02774e+07   1.62876e+06             90481
# 9               2.92421      4.05258e+06        125920              3075
# 10             0.324752      3.52768e+07        446300              4047
# 11              2.61903       1.8599e+08        910770              1182
# ...

# %%
df2.drop(['International Visitors_D'], axis=1, inplace=True)
df2
# Out:
#       Population growth Total population Area (sq. km) Coronavirus Cases  \
# index
# 0              0.817556      2.07653e+08   8.35814e+06             59324
# 1               1.07722       8.3721e+06         39516             29061
# 2               1.19387      8.26677e+07        348900            156727
# 3              0.834638      2.16818e+07         42262              8575
# 4           -0.00804809       4.6444e+07        500210            223759
# 5              0.407491      6.68961e+07        547557            161488
# 6             -0.115284      1.26995e+08        364560             13231
# 7             -0.687543      1.07467e+07        128900              2506
# 8               1.14879      8.02774e+07   1.62876e+06             90481
# 9               2.92421      4.05258e+06        125920              3075
# 10             0.324752      3.52768e+07        446300              4047
# 11              2.61903       1.8599e+08        910770              1182
# ...

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler,Normalizer,StandardScaler

# %% [markdown]
# ### MinMaxScaler

# %%
T=MinMaxScaler(feature_range=(0, 1))
df_MinMax = pd.DataFrame(T.fit_transform(df2.drop(['International Visitors_A', 'International Visitors_B', 'International Visitors_C'], axis=1 )))
df_MinMax = df_MinMax.rename(columns={0: 'Population growth', 1: 'Total population', 2: 'Area (sq. km)', 3: 'Coronavirus Cases'})
df_MinMax
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases
# 0            0.359846          0.155178       1.000000           0.261222
# 1            0.421929          0.004390       0.003343           0.125256
# 2            0.449817          0.060607       0.040411           0.698837
# 3            0.363930          0.014461       0.003672           0.033215
# 4            0.162457          0.033198       0.058539           1.000000
# 5            0.261806          0.048673       0.064212           0.720227
# 6            0.136818          0.094147       0.042287           0.054134
# 7            0.000000          0.006187       0.014053           0.005949
# 8            0.439039          0.058798       0.193751           0.401205
# 9            0.863515          0.001122       0.013695           0.008505
# 10           0.242024          0.024748       0.052080           0.012872
# 11           0.790553          0.138786       0.107729           0.000000
# ...

# %% [markdown]
# ### Normalizer

# %%
T=Normalizer()
df_normalizer=pd.DataFrame(T.fit_transform(df2.drop(['International Visitors_A', 'International Visitors_B', 'International Visitors_C'], axis=1 )))
df_normalizer= df_normalizer.rename(columns={0: 'Population growth', 1: 'Total population', 2: 'Area (sq. km)', 3: 'Coronavirus Cases'})
df_normalizer
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases
# 0        3.933941e-09          0.999191       0.040218           0.000285
# 1        1.286658e-07          0.999983       0.004720           0.003471
# 2        1.444160e-08          0.999989       0.004220           0.001896
# 3        3.849480e-08          0.999998       0.001949           0.000395
# 4       -1.732739e-10          0.999930       0.010769           0.004817
# 5        6.091179e-09          0.999964       0.008185           0.002414
# 6       -9.077849e-10          0.999996       0.002871           0.000104
# 7       -6.397224e-08          0.999928       0.011993           0.000233
# 8        1.430728e-08          0.999794       0.020285           0.001127
# 9        7.212176e-07          0.999517       0.031056           0.000758
# 10       9.205086e-09          0.999920       0.012650           0.000115
# 11       1.408144e-08          0.999988       0.004897           0.000006
# ...

# %% [markdown]
# ### StandardScaler

# %%
T=StandardScaler()
df_standard=pd.DataFrame(T.fit_transform(df2.drop(['International Visitors_A', 'International Visitors_B', 'International Visitors_C'], axis=1 )))
df_standard = df_standard.rename(columns={0: 'Population growth', 1: 'Total population', 2: 'Area (sq. km)', 3: 'Coronavirus Cases'})
df_standard
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases
# 0           -0.265443          0.187332       3.489602           0.078032
# 1           -0.032864         -0.434106      -0.522168          -0.361669
# 2            0.071614         -0.202422      -0.372964           1.493232
# 3           -0.250143         -0.392601      -0.520844          -0.659316
# 4           -1.004926         -0.315382      -0.299992           2.467161
# 5           -0.632733         -0.251604      -0.277159           1.562406
# 6           -1.100976         -0.064193      -0.365411          -0.591668
# 7           -1.613541         -0.426701      -0.479062          -0.747495
# 8            0.031239         -0.209876       0.244266           0.530722
# 9            1.621459         -0.447576      -0.480499          -0.739228
# 10          -0.706841         -0.350206      -0.325991          -0.725105
# 11           1.348119          0.119778      -0.101994          -0.766732
# ...

# %%
df_dummy = df2.iloc[:,4:7]
df_dummy
# Out:
#        International Visitors_A  International Visitors_B  \
# index
# 0                             0                         1
# 1                             0                         1
# 2                             1                         0
# 3                             0                         1
# 4                             1                         0
# 5                             1                         0
# 6                             0                         1
# 7                             0                         0
# 8                             0                         0
# 9                             0                         0
# 10                            0                         0
# 11                            0                         0
# 12                            0                         1
# 13                            0                         0
# 14                            0                         1
#
# ...

# %%
df_standard = df_standard.join(df_dummy)
df_standard = df_standard.rename(columns={0: 'Population growth', 1: 'Total population', 2: 'Area (sq. km)', 3: 'Coronavirus Cases'})
df_standard
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0           -0.265443          0.187332       3.489602           0.078032
# 1           -0.032864         -0.434106      -0.522168          -0.361669
# 2            0.071614         -0.202422      -0.372964           1.493232
# 3           -0.250143         -0.392601      -0.520844          -0.659316
# 4           -1.004926         -0.315382      -0.299992           2.467161
# 5           -0.632733         -0.251604      -0.277159           1.562406
# 6           -1.100976         -0.064193      -0.365411          -0.591668
# 7           -1.613541         -0.426701      -0.479062          -0.747495
# 8            0.031239         -0.209876       0.244266           0.530722
# 9            1.621459         -0.447576      -0.480499          -0.739228
# 10          -0.706841         -0.350206      -0.325991          -0.725105
# 11           1.348119          0.119778      -0.101994          -0.766732
# ...

# %%
y_standard=df_standard.iloc[:,3]
y_standard
# Out:
# 0     0.078032
# 1    -0.361669
# 2     1.493232
# 3    -0.659316
# 4     2.467161
# 5     1.562406
# 6    -0.591668
# 7    -0.747495
# 8     0.530722
# 9    -0.739228
# 10   -0.725105
# 11   -0.766732
# 12   -0.634442
# 13   -0.513079
# 14   -0.392820
# Name: Coronavirus Cases, dtype: float64

# %%
X_standard=df_standard.drop(['Coronavirus Cases'], axis=1)
X_standard
# Out:
#     Population growth  Total population  Area (sq. km)  \
# 0           -0.265443          0.187332       3.489602
# 1           -0.032864         -0.434106      -0.522168
# 2            0.071614         -0.202422      -0.372964
# 3           -0.250143         -0.392601      -0.520844
# 4           -1.004926         -0.315382      -0.299992
# 5           -0.632733         -0.251604      -0.277159
# 6           -1.100976         -0.064193      -0.365411
# 7           -1.613541         -0.426701      -0.479062
# 8            0.031239         -0.209876       0.244266
# 9            1.621459         -0.447576      -0.480499
# 10          -0.706841         -0.350206      -0.325991
# 11           1.348119          0.119778      -0.101994
# 12           2.132775         -0.452200      -0.535626
# 13           0.371537         -0.429331      -0.344795
# 14           0.030724          3.669089       0.892636
#
#     International Visitors_A  International Visitors_B  \
# ...

# %% [markdown]
# # outlier

# %% [markdown]
# ### z-score

# %%
from scipy import stats 
z=np.abs(stats.zscore(df_standard))
z
# Out:
# array([[0.26544284, 0.18733223, 3.48960244, 0.07803214, 0.5       ,
#         1.22474487, 0.60302269],
#        [0.03286358, 0.43410582, 0.52216832, 0.36166872, 0.5       ,
#         1.22474487, 0.60302269],
#        [0.07161448, 0.20242212, 0.37296364, 1.49323166, 2.        ,
#         0.81649658, 0.60302269],
#        [0.25014278, 0.39260084, 0.52084403, 0.6593164 , 0.5       ,
#         1.22474487, 0.60302269],
#        [1.00492632, 0.31538235, 0.29999231, 2.46716114, 2.        ,
#         0.81649658, 0.60302269],
#        [0.63273288, 0.25160428, 0.27715857, 1.56240576, 2.        ,
#         0.81649658, 0.60302269],
#        [1.10097641, 0.06419315, 0.36541139, 0.59166788, 0.5       ,
#         1.22474487, 0.60302269],
#        [1.61354141, 0.42670072, 0.47906166, 0.74749485, 0.5       ,
#         0.81649658, 1.6583124 ],
#        [0.03123851, 0.20987591, 0.24426644, 0.53072222, 0.5       ,
#         0.81649658, 0.60302269],
# ...

# %%
print(np.where(z>3))
# Out:
# (array([ 0, 14], dtype=int64), array([2, 1], dtype=int64))

# %%
z[0][2]
# Out:
# 3.489602436496127

# %% [markdown]
# ### IQR Score

# %%
Q1=df_standard.quantile(0.25)
Q1
# Out:
# Population growth          -0.669787
# Total population           -0.428016
# Area (sq. km)              -0.479780
# Coronavirus Cases          -0.692211
# International Visitors_A    0.000000
# International Visitors_B    0.000000
# International Visitors_C    0.000000
# Name: 0.25, dtype: float64

# %%
Q3=df_standard.quantile(0.75)
Q3
# Out:
# Population growth           0.221576
# Total population           -0.133308
# Area (sq. km)              -0.189576
# Coronavirus Cases           0.304377
# International Visitors_A    0.000000
# International Visitors_B    1.000000
# International Visitors_C    0.500000
# Name: 0.75, dtype: float64

# %%
IQR=Q3-Q1
IQR
# Out:
# Population growth           0.891363
# Total population            0.294708
# Area (sq. km)               0.290204
# Coronavirus Cases           0.996588
# International Visitors_A    0.000000
# International Visitors_B    1.000000
# International Visitors_C    0.500000
# dtype: float64

# %%
(df_standard<Q1-1.5*IQR)|(df_standard>Q3+1.5*IQR)
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0               False             False           True              False
# 1               False             False          False              False
# 2               False             False          False              False
# 3               False             False          False              False
# 4               False             False          False               True
# 5               False             False          False              False
# 6               False             False          False              False
# 7               False             False          False              False
# 8               False             False          False              False
# 9                True             False          False              False
# 10              False             False          False              False
# 11              False             False          False              False
# ...

# %% [markdown]
# ### Removing

# %%
df_zScore=df_standard[(z<3).all(axis=1)]
df_zScore.shape
# Out:
# (13, 7)

# %%
df_IQR=df_standard[((df_standard>=Q1-1.5*IQR)&(df_standard<=Q3+1.5*IQR)).all(axis=1)]
df_IQR.shape
# Out:
# (8, 7)

# %% [markdown]
# # work with outlier

# %% [markdown]
# ### X and y arrays with outlier

# %%
X_standard
# Out:
#     Population growth  Total population  Area (sq. km)  \
# 0           -0.265443          0.187332       3.489602
# 1           -0.032864         -0.434106      -0.522168
# 2            0.071614         -0.202422      -0.372964
# 3           -0.250143         -0.392601      -0.520844
# 4           -1.004926         -0.315382      -0.299992
# 5           -0.632733         -0.251604      -0.277159
# 6           -1.100976         -0.064193      -0.365411
# 7           -1.613541         -0.426701      -0.479062
# 8            0.031239         -0.209876       0.244266
# 9            1.621459         -0.447576      -0.480499
# 10          -0.706841         -0.350206      -0.325991
# 11           1.348119          0.119778      -0.101994
# 12           2.132775         -0.452200      -0.535626
# 13           0.371537         -0.429331      -0.344795
# 14           0.030724          3.669089       0.892636
#
#     International Visitors_A  International Visitors_B  \
# ...

# %%
y_standard
# Out:
# 0     0.078032
# 1    -0.361669
# 2     1.493232
# 3    -0.659316
# 4     2.467161
# 5     1.562406
# 6    -0.591668
# 7    -0.747495
# 8     0.530722
# 9    -0.739228
# 10   -0.725105
# 11   -0.766732
# 12   -0.634442
# 13   -0.513079
# 14   -0.392820
# Name: Coronavirus Cases, dtype: float64

# %% [markdown]
# ### Train Test split

# %%
X_train_standard=X_standard
y_train_standard=y_standard

# %% [markdown]
# ### Creating and Training the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm_standard=LinearRegression()
lm_standard.fit(X_train_standard, y_train_standard)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm_standard.intercept_
# Out:
# -0.06715520705276215

# %%
lm_standard.coef_
# Out:
# array([-0.09463343, -0.04415957,  0.17470448,  1.90269217, -0.40421302,
#        -0.56886756])

# %%
coef_df_standard=pd.DataFrame(lm_standard.coef_, X_standard.columns, columns=['Coefficient'])
coef_df_standard
# Out:
#                           Coefficient
# Population growth           -0.094633
# Total population            -0.044160
# Area (sq. km)                0.174704
# International Visitors_A     1.902692
# International Visitors_B    -0.404213
# International Visitors_C    -0.568868

# %% [markdown]
# ### Prediction from our model

# %%
prediction_train_standard=lm_standard.predict(X_train_standard)
plt.scatter(y_train_standard,prediction_train_standard)

# %% [markdown]
# ### Regression Evaluation metrics

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_train_standard,prediction_train_standard))
print('MSE:', metrics.mean_squared_error(y_train_standard,prediction_train_standard))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train_standard,prediction_train_standard)))
# Out:
# MAE: 0.24216590859443152
# MSE: 0.08721556385266056
# RMSE: 0.2953228129567043

# %% [markdown]
# ### statsmodel

# %%
import statsmodels.formula.api as smf

# %%
lm1_standard=smf.ols(formula='Q("Coronavirus Cases")~Q("Population growth")+Q("Total population")+Q("Area (sq. km)")+Q("International Visitors_A")+Q("International Visitors_B")+Q("International Visitors_C")', data=df_standard).fit()

# %%
lm1_standard.params
# Out:
# Intercept                       -0.067155
# Q("Population growth")          -0.094633
# Q("Total population")           -0.044160
# Q("Area (sq. km)")               0.174704
# Q("International Visitors_A")    1.902692
# Q("International Visitors_B")   -0.404213
# Q("International Visitors_C")   -0.568868
# dtype: float64

# %%
lm1_standard.conf_int()
# Out:
#                                       0         1
# Intercept                     -0.751673  0.617362
# Q("Population growth")        -0.354805  0.165538
# Q("Total population")         -0.312333  0.224014
# Q("Area (sq. km)")            -0.096549  0.445958
# Q("International Visitors_A")  0.983327  2.822058
# Q("International Visitors_B") -1.189968  0.381541
# Q("International Visitors_C") -1.417614  0.279879

# %%
lm1_standard.pvalues
# Out:
# Intercept                        0.826694
# Q("Population growth")           0.425947
# Q("Total population")            0.714031
# Q("Area (sq. km)")               0.175789
# Q("International Visitors_A")    0.001404
# Q("International Visitors_B")    0.269549
# Q("International Visitors_C")    0.160787
# dtype: float64

# %%
lm1_standard.summary()
# Out:
# D:\Anaconda\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Q("Coronavirus Cases")   R-squared:                       0.913
# Model:                                OLS   Adj. R-squared:                  0.847
# Method:                     Least Squares   F-statistic:                     13.95
# Date:                    Mon, 09 Jan 2023   Prob (F-statistic):           0.000751
# Time:                            14:18:26   Log-Likelihood:                -2.9888
# No. Observations:                      15   AIC:                             19.98
# Df Residuals:                           8   BIC:                             24.93
# Df Model:                               6
# Covariance Type:                nonrobust
# ...

# %% [markdown]
# # work without outlier(removing with IQR)

# %% [markdown]
# ### X and y arrays

# %%
X_IQR=df_IQR.drop(['Coronavirus Cases'], axis=1)
X_IQR
# Out:
#     Population growth  Total population  Area (sq. km)  \
# 1           -0.032864         -0.434106      -0.522168
# 3           -0.250143         -0.392601      -0.520844
# 6           -1.100976         -0.064193      -0.365411
# 7           -1.613541         -0.426701      -0.479062
# 8            0.031239         -0.209876       0.244266
# 10          -0.706841         -0.350206      -0.325991
# 11           1.348119          0.119778      -0.101994
# 13           0.371537         -0.429331      -0.344795
#
#     International Visitors_A  International Visitors_B  \
# 1                          0                         1
# 3                          0                         1
# 6                          0                         1
# 7                          0                         0
# 8                          0                         0
# 10                         0                         0
# 11                         0                         0
# ...

# %%
y_IQR=df_IQR.iloc[:,3]
y_IQR
# Out:
# 1    -0.361669
# 3    -0.659316
# 6    -0.591668
# 7    -0.747495
# 8     0.530722
# 10   -0.725105
# 11   -0.766732
# 13   -0.513079
# Name: Coronavirus Cases, dtype: float64

# %% [markdown]
# ### Train Test Split

# %%
X_train_IQR=X_IQR
y_train_IQR=y_IQR

# %% [markdown]
# ### Creating and Training the model

# %%
lm_IQR=LinearRegression()
lm_IQR.fit(X_train_IQR, y_train_IQR)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm_IQR.intercept_
# Out:
# -0.3132925067881224

# %%
lm_IQR.coef_
# Out:
# array([-3.67246928e-02, -1.48997451e+00,  2.15774745e+00,  2.22044605e-16,
#         3.29334308e-01, -1.44518670e-01])

# %%
coef_df_IQR=pd.DataFrame(lm_IQR.coef_, X_IQR.columns, columns=['Coefficient'])
coef_df_IQR
# Out:
#                            Coefficient
# Population growth        -3.672469e-02
# Total population         -1.489975e+00
# Area (sq. km)             2.157747e+00
# International Visitors_A  2.220446e-16
# International Visitors_B  3.293343e-01
# International Visitors_C -1.445187e-01

# %% [markdown]
# ### Prediction from our model

# %%
prediction_train_IQR=lm_IQR.predict(X_train_IQR)
plt.scatter(y_train_IQR, prediction_train_IQR)

# %% [markdown]
# ### Regression Evaluation metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_train_IQR,prediction_train_IQR))
print('MSE:', metrics.mean_squared_error(y_train_IQR,prediction_train_IQR))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train_IQR,prediction_train_IQR)))
# Out:
# MAE: 0.06567275731492234
# MSE: 0.006532343008050172
# RMSE: 0.08082291140543114

# %% [markdown]
# ### statsmodel

# %%
lm1_IQR=smf.ols(formula='Q("Coronavirus Cases")~Q("Population growth")+Q("Total population")+Q("Area (sq. km)")+Q("International Visitors_A")+Q("International Visitors_B")+Q("International Visitors_C")', data=df_IQR).fit()

# %%
lm1_IQR.params
# Out:
# Intercept                       -3.132925e-01
# Q("Population growth")          -3.672469e-02
# Q("Total population")           -1.489975e+00
# Q("Area (sq. km)")               2.157747e+00
# Q("International Visitors_A")    1.248897e-16
# Q("International Visitors_B")    3.293343e-01
# Q("International Visitors_C")   -1.445187e-01
# dtype: float64

# %%
lm1_IQR.conf_int()
# Out:
#                                           0             1
# Intercept                     -9.332590e-01  3.066740e-01
# Q("Population growth")        -4.372073e-01  3.637580e-01
# Q("Total population")         -3.372140e+00  3.921905e-01
# Q("Area (sq. km)")            -3.567444e-01  4.672239e+00
# Q("International Visitors_A")  2.174123e-17  2.280382e-16
# Q("International Visitors_B") -1.513348e+00  2.172017e+00
# Q("International Visitors_C") -1.936147e+00  1.647110e+00

# %%
lm1_IQR.pvalues
# Out:
# Intercept                        0.161719
# Q("Population growth")           0.731268
# Q("Total population")            0.076443
# Q("Area (sq. km)")               0.066158
# Q("International Visitors_A")    0.034928
# Q("International Visitors_B")    0.522295
# Q("International Visitors_C")    0.761660
# dtype: float64

# %%
lm1_IQR.summary()
# Out:
# D:\Anaconda\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Q("Coronavirus Cases")   R-squared:                       0.960
# Model:                                OLS   Adj. R-squared:                  0.859
# Method:                     Least Squares   F-statistic:                     9.513
# Date:                    Mon, 09 Jan 2023   Prob (F-statistic):             0.0978
# Time:                            14:18:44   Log-Likelihood:                 8.7725
# No. Observations:                       8   AIC:                            -5.545
# Df Residuals:                           2   BIC:                            -5.068
# Df Model:                               5
# Covariance Type:                nonrobust
# ...

# %% [markdown]
# # work without outlier(removing with z-score)

# %% [markdown]
# ### X and y arrays

# %%
X_zScore=df_zScore.drop(['Coronavirus Cases'], axis=1)
X_zScore
# Out:
#     Population growth  Total population  Area (sq. km)  \
# 1           -0.032864         -0.434106      -0.522168
# 2            0.071614         -0.202422      -0.372964
# 3           -0.250143         -0.392601      -0.520844
# 4           -1.004926         -0.315382      -0.299992
# 5           -0.632733         -0.251604      -0.277159
# 6           -1.100976         -0.064193      -0.365411
# 7           -1.613541         -0.426701      -0.479062
# 8            0.031239         -0.209876       0.244266
# 9            1.621459         -0.447576      -0.480499
# 10          -0.706841         -0.350206      -0.325991
# 11           1.348119          0.119778      -0.101994
# 12           2.132775         -0.452200      -0.535626
# 13           0.371537         -0.429331      -0.344795
#
#     International Visitors_A  International Visitors_B  \
# 1                          0                         1
# 2                          1                         0
# ...

# %%
y_zScore=df_zScore.iloc[:,3]
y_zScore
# Out:
# 1    -0.361669
# 2     1.493232
# 3    -0.659316
# 4     2.467161
# 5     1.562406
# 6    -0.591668
# 7    -0.747495
# 8     0.530722
# 9    -0.739228
# 10   -0.725105
# 11   -0.766732
# 12   -0.634442
# 13   -0.513079
# Name: Coronavirus Cases, dtype: float64

# %% [markdown]
# ### Train Test Split

# %%
X_train_zScore=X_zScore
y_train_zScore=y_zScore

# %% [markdown]
# ### Creating and Training the model

# %%
lm_zScore=LinearRegression()
lm_zScore.fit(X_train_zScore, y_train_zScore)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm_zScore.intercept_
# Out:
# -0.28679706284080847

# %%
lm_zScore.coef_
# Out:
# array([-0.06815695, -1.7562545 ,  1.92139823,  2.25024123,  0.08189958,
#        -0.34300141])

# %%
coef_df_zScore=pd.DataFrame(lm_zScore.coef_, X_zScore.columns, columns=['Coefficient'])
coef_df_zScore
# Out:
#                           Coefficient
# Population growth           -0.068157
# Total population            -1.756255
# Area (sq. km)                1.921398
# International Visitors_A     2.250241
# International Visitors_B     0.081900
# International Visitors_C    -0.343001

# %% [markdown]
# ### Prediction from our model

# %%
prediction_train_zScore=lm_zScore.predict(X_train_zScore)
plt.scatter(y_train_zScore, prediction_train_zScore)

# %% [markdown]
# ### Regression Evaluation metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_train_zScore,prediction_train_zScore))
print('MSE:', metrics.mean_squared_error(y_train_zScore,prediction_train_zScore))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train_zScore,prediction_train_zScore)))
# Out:
# MAE: 0.1344959167185707
# MSE: 0.033802614195588436
# RMSE: 0.18385487264575948

# %% [markdown]
# ### statsmodel

# %%
lm1_zScore=smf.ols(formula='Q("Coronavirus Cases")~Q("Population growth")+Q("Total population")+Q("Area (sq. km)")+Q("International Visitors_A")+Q("International Visitors_B")+Q("International Visitors_C")', data=df_zScore).fit()

# %%
lm1_zScore.params
# Out:
# Intercept                       -0.286797
# Q("Population growth")          -0.068157
# Q("Total population")           -1.756255
# Q("Area (sq. km)")               1.921398
# Q("International Visitors_A")    2.250241
# Q("International Visitors_B")    0.081900
# Q("International Visitors_C")   -0.343001
# dtype: float64

# %%
lm1_zScore.conf_int()
# Out:
#                                       0         1
# Intercept                     -0.823328  0.249734
# Q("Population growth")        -0.284851  0.148537
# Q("Total population")         -3.458793 -0.053716
# Q("Area (sq. km)")            -0.424886  4.267683
# Q("International Visitors_A")  0.902772  3.597711
# Q("International Visitors_B") -1.570115  1.733914
# Q("International Visitors_C") -1.938164  1.252162

# %%
lm1_zScore.pvalues
# Out:
# Intercept                        0.238757
# Q("Population growth")           0.470724
# Q("Total population")            0.045036
# Q("Area (sq. km)")               0.091941
# Q("International Visitors_A")    0.006456
# Q("International Visitors_B")    0.907408
# Q("International Visitors_C")    0.617657
# dtype: float64

# %%
lm1_zScore.summary()
# Out:
# D:\Anaconda\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Q("Coronavirus Cases")   R-squared:                       0.970
# Model:                                OLS   Adj. R-squared:                  0.941
# Method:                     Least Squares   F-statistic:                     32.75
# Date:                    Mon, 09 Jan 2023   Prob (F-statistic):           0.000249
# Time:                            14:18:49   Log-Likelihood:                 3.5707
# No. Observations:                      13   AIC:                             6.859
# Df Residuals:                           6   BIC:                             10.81
# Df Model:                               6
# Covariance Type:                nonrobust
# ...

# %% [markdown]
# # Multiple Regression (power 2)

# %%
df_zScore
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 1           -0.032864         -0.434106      -0.522168          -0.361669
# 2            0.071614         -0.202422      -0.372964           1.493232
# 3           -0.250143         -0.392601      -0.520844          -0.659316
# 4           -1.004926         -0.315382      -0.299992           2.467161
# 5           -0.632733         -0.251604      -0.277159           1.562406
# 6           -1.100976         -0.064193      -0.365411          -0.591668
# 7           -1.613541         -0.426701      -0.479062          -0.747495
# 8            0.031239         -0.209876       0.244266           0.530722
# 9            1.621459         -0.447576      -0.480499          -0.739228
# 10          -0.706841         -0.350206      -0.325991          -0.725105
# 11           1.348119          0.119778      -0.101994          -0.766732
# 12           2.132775         -0.452200      -0.535626          -0.634442
# ...

# %%
DF=df_zScore[['Total population']]
DF['Total population**2'] = df_zScore['Total population']**2
DF
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Total population  Total population**2
# 1          -0.434106             0.188448
# 2          -0.202422             0.040975
# 3          -0.392601             0.154135
# 4          -0.315382             0.099466
# 5          -0.251604             0.063305
# 6          -0.064193             0.004121
# 7          -0.426701             0.182074
# 8          -0.209876             0.044048
# 9          -0.447576             0.200324
# 10         -0.350206             0.122644
# 11          0.119778             0.014347
# 12         -0.452200             0.204485
# 13         -0.429331             0.184326

# %%
y=df_zScore.iloc[:,3]
y
# Out:
# 1    -0.361669
# 2     1.493232
# 3    -0.659316
# 4     2.467161
# 5     1.562406
# 6    -0.591668
# 7    -0.747495
# 8     0.530722
# 9    -0.739228
# 10   -0.725105
# 11   -0.766732
# 12   -0.634442
# 13   -0.513079
# Name: Coronavirus Cases, dtype: float64

# %% [markdown]
# ### Creating and Trainung the model

# %%
X_train=DF
y_train=y

# %%
lm2=LinearRegression()
lm2.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm2.intercept_
# Out:
# 0.2152342144746882

# %%
lm2.coef_
# Out:
# array([ -8.8699869 , -24.41588806])

# %%
coef_df_new=pd.DataFrame(lm2.coef_, DF.columns, columns=['Coefficient'])
coef_df_new
# Out:
#                      Coefficient
# Total population       -8.869987
# Total population**2   -24.415888

# %% [markdown]
# ### Prediction from our model

# %%
Predict_train=lm2.predict(X_train)
plt.scatter(y_train,Predict_train)

# %% [markdown]
# ### Regression Evaluation metrics

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_train,Predict_train))
print('MSE:', metrics.mean_squared_error(y_train,Predict_train))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train,Predict_train)))
# Out:
# MAE: 0.5790029080229346
# MSE: 0.60393893724423
# RMSE: 0.7771350830095306

# %%
DF1 = DF.join(y)
DF1
# Out:
#     Total population  Total population**2  Coronavirus Cases
# 1          -0.434106             0.188448          -0.361669
# 2          -0.202422             0.040975           1.493232
# 3          -0.392601             0.154135          -0.659316
# 4          -0.315382             0.099466           2.467161
# 5          -0.251604             0.063305           1.562406
# 6          -0.064193             0.004121          -0.591668
# 7          -0.426701             0.182074          -0.747495
# 8          -0.209876             0.044048           0.530722
# 9          -0.447576             0.200324          -0.739228
# 10         -0.350206             0.122644          -0.725105
# 11          0.119778             0.014347          -0.766732
# 12         -0.452200             0.204485          -0.634442
# 13         -0.429331             0.184326          -0.513079

# %% [markdown]
# ### stasmodel

# %%
lm2_DF1=smf.ols(formula='Q("Coronavirus Cases")~Q("Total population")+Q("Total population**2")', data=DF1).fit()

# %%
lm2_DF1.params
# Out:
# Intercept                    0.215234
# Q("Total population")       -8.869987
# Q("Total population**2")   -24.415888
# dtype: float64

# %%
lm2_DF1.conf_int()
# Out:
#                                   0         1
# Intercept                 -0.905968  1.336436
# Q("Total population")    -16.908203 -0.831771
# Q("Total population**2") -42.955966 -5.875810

# %%
lm2_DF1.pvalues
# Out:
# Intercept                   0.677912
# Q("Total population")       0.033751
# Q("Total population**2")    0.014931
# dtype: float64

# %%
lm2_DF1.summary()
# Out:
# D:\Anaconda\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Q("Coronavirus Cases")   R-squared:                       0.471
# Model:                                OLS   Adj. R-squared:                  0.365
# Method:                     Least Squares   F-statistic:                     4.446
# Date:                    Sat, 13 Jun 2020   Prob (F-statistic):             0.0416
# Time:                            22:06:41   Log-Likelihood:                -15.168
# No. Observations:                      13   AIC:                             36.34
# Df Residuals:                          10   BIC:                             38.03
# Df Model:                               2
# Covariance Type:                nonrobust
# ...
